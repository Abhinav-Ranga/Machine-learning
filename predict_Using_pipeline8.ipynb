# %% [markdown]
# if u do any changes then u just have to download new file and put in folder pipeline will be still there
# nothing is changing in these code .
#
# if u are using pipeline then u no need to change anything in production
# u just have to change file no need to change in code

# %%
import pickle 
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = np.array([2,'male',31.0,0,0,10.5,'5'],dtype = object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
