# %% [markdown]
# # What are outliers

# %% [markdown]
# ![image.png](attachment:b9fe60d1-340e-46a6-949a-e0683237e9a0.png)
#
# An observation that behaves differently than other observations.

# %% [markdown]
#  What is outlier dangerous
#
#  ![image.png](attachment:55139564-099a-4ec7-a1c6-cc3878ef34fb.png)

# %% [markdown]
# Effect of outliers on ML algorithms
#
# ![image.png](attachment:3b170064-645b-4a0a-8bb8-6a155c029dcd.png)
#
# there are certain set of algorithms on which there is a bad impact of outliers
# ex = LinearRegression, LogisticRegression , Adaboose etc
#
# common pattern in these algorithm  = we calculate  weight
#
#
# * trick to findout whether this outlier will impact my ML algorithm or not :
#
#    check are u working on weight based algorithm or not  coz outliers
#   create a bad impact on weight based algorithms

# %% [markdown]
# # How to treat outliers
#
# ![image.png](attachment:daafc465-8b7e-489d-9d35-7b63a4cdc87f.png)
#
#
# *  trimming = we remove our outliers
#
# this is fast but if  there are multiple outliers then our data becomes thin
#
#
# * capping = we set limit  ex =  < 3  and  >5 is an outlier
#
#
# * we use missing values also
#
# * discretization = we discreticize our numerical data means we do :
#
#    40 - 60  will be in one 80 to 100 will be in one

# %% [markdown]
# # How to detect outliers
#
# ![image.png](attachment:2f4b33e0-6317-4e89-af67-a9bbec8c9a9e.png)
#
# so in normal distribution our
#
# 68 % observations lie in 1 standard deviation
#
# 95.4% in 2 standard deviation
#
# 99.7%  in standard deviation
#
#
# so if our any particular observation is outside of mean+3 sd and mean - 3d it is an  outlier. It is
# applicable when ur data is close to normal or normally distributed

# %% [markdown]
# ![image.png](attachment:2ad9879d-fbcc-42b8-826d-84b563a1caf5.png)
#
# when our data is skewed
#
#
# if our range is  < q1-1.5 IQR and > q3+1.5 IQR it is an outlier

# %% [markdown]
# ![image.png](attachment:924bdbb5-42f8-4cca-a471-9e4959dae190.png)
#
# other distribution
#
#
# when our data is greater than 92.5 percentile  and lesser than  2.5 percentile is an outlier
# {we can take any ranges its up to us  }

# %% [markdown]
# ![image.png](attachment:41332098-c2b1-437b-b025-0ab7850ea83a.png)
